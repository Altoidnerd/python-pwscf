# %%
import efg
import md
import sys
import numpy as np
import os
import nqr_parser as nqr
import datetime

################CHANGE THESE AS NEEDED##############
TEMP=293
TARGET_DIR='/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs'
TARGET_SPECIES='N'
####################################################



os.chdir(TARGET_DIR) 
starttime=datetime.datetime.now()


print("Begin on {}".format(starttime.ctime()))
print("\nWorking dir:\t{}".format(os.getcwd())) 
print("""

TEMP:            {}
TARGET_DIR:      {}
TARGET_SPECIES:  {}
""".format(TEMP,TARGET_DIR,TARGET_SPECIES)
     )

print()




def theta_x(xi,yi,zi,xf,yf,zf):
    return np.arcsin(zf@yi)

def theta_y(xi,yi,zi,xf,yf,zf):
    thetax = theta_x(xi,yi,zi,xf,yf,zf)
    return zf@xi/np.cos(thetax)

def normalize(vector):
    return vector/np.linalg.norm(vector)

def ntheta_x(xi,yi,zi,xf,yf,zf):
    n=normalize
    xi,yi,zi,xf,yf,zf=n(xi),n(yi),n(zi),n(xf),n(yf),n(zf)
    return np.arcsin(zf@yi)

def ntheta_y(xi,yi,zi,xf,yf,zf):
    n=normalize
    xi,yi,zi,xf,yf,zf=n(xi),n(yi),n(zi),n(xf),n(yf),n(zf)
    thetax = theta_x(xi,yi,zi,xf,yf,zf)
    return zf@xi/np.cos(thetax)



ls = os.listdir('.') 
efgfiles = [ thing for thing in ls if thing.startswith('efg') and thing.endswith('out') ]
numfiles= len(efgfiles) 
print("There are {} efg files in this directory.".format(numfiles))
print()



efgs=[] 
skipped_files=[]
for i in range(numfiles): 
    infile='efg.{}.out'.format(i) 
    try:
        efgs.append(efg.Efg(infile))
    except FileNotFoundError:
        skipped_files.append(infile)
        #print('skipped file {}'.format(infile))

if len(skipped_files) != 0:
    print('{} files were skipped.'.format(len(skipped_files)))
    print('between {} and {}'.format(skipped_files[0], skipped_files[-1]))
    print('display variable "skipped_files" to see all files not opened.')
print("{} efg files opened without error.".format(len(efgs)))
print()



print("The indices of {} atoms are:".format(TARGET_SPECIES)) 
target_atom_labels=[] 
for label in efgs[0].atom_labels: 
    if TARGET_SPECIES in label: 
        new_index = efgs[0].atom_labels.index(label)+1 
        target_atom_labels.append(new_index) 
        sys.stdout.write(str(new_index)+' ') 

print()





av_theta_xs = [] 
av_theta_ys = [] 
av_theta_y2s = [] 
av_theta_x2s = [] 
cq_coef0s = [] 
cq_coef1s = [] 
eta_coefs = [] 
cq0s = [] 
cqprime0s = [] 
cqprime1s = [] 
eta0s = [] 
etaprimes = [] 
fq0s = [] 
fqprimes = []

for atnum in target_atom_labels: 
    efg0 = efgs[0] 
    specie=atnum 
    k=specie 
    print("\nWorking on atomic specie:\t{}".format(specie)) 
    
    
    this_nucleus=efg0.atom(k) 
    cq0=this_nucleus.cq 
    cq0s.append(cq0) 
    eta0=this_nucleus.eta
    eta0s.append(eta0)
    
    
    xi=efg0.atom(k).x
    yi=efg0.atom(k).y
    zi=efg0.atom(k).z



    theta_x_vec=[]
    theta_y_vec=[]


    print("Fetching the angles in file efg.{}.out")
    for i in range(1,901):
        try:
            nucleus=efgs[i].atom(k)
            nuc=nucleus
            xf,yf,zf=nuc.x,nuc.y,nuc.z
            args=(xi,yi,zi,xf,yf,zf)
            #print("thetaX{}\t".format(i),"\t", theta_x(xi,yi,zi,xf,yf,zf),"\t", "thetaY{}\t".format(i), theta_y(xi,yi,zi,xf,yf,zf))
            theta_x_vec.append(theta_x(*args))
            theta_y_vec.append(theta_y(*args))
            sys.stdout.write("{} \r".format(i))
        except IndexError:
            sys.stdout.write("skipped:{}\n".format(i))
        
  
                 # theta_x squareds and theta_y squareds
    theta_x2_vec=[angle**2 for angle in theta_x_vec]
    theta_y2_vec=[angle**2 for angle in theta_y_vec]

    av=np.average
    av_theta_x  = av(theta_x_vec)
    av_theta_y  = av(theta_y_vec)
    av_theta_x2 = av(theta_x2_vec)
    av_theta_y2 = av(theta_y2_vec)

    av_theta_xs.append(av_theta_x)
    av_theta_ys.append(av_theta_y)
    av_theta_x2s.append(av_theta_x2)
    av_theta_y2s.append(av_theta_y2)

    print("\nReport for atomic specie:\t{}".format(k))
    print("Working Dir:\t{}".format(os.getcwd()))
    print("<tx>:\t",av_theta_x,"\t<ty>:\t",   av_theta_y,"\n",
      "<tx^2>\t:",av_theta_x2,"\t<ty^2>:", av_theta_y2,"\n")

    print("cq0=\t{}".format(cq0))
    print("eta0=\t{}".format(eta0))

    cq_coef0 = 1 - 3/2*(av_theta_x2 + av_theta_y2)
    cq_coef0s.append(cq_coef0)
    cq_coef1 = 1 - 3/2*(av_theta_x2 + av_theta_y2 - 1/2*eta0*(av_theta_x2 - av_theta_y2))
    cq_coef1s.append(cq_coef1)

    
    
    print("==================================")
    print("target:\t"+TARGET_DIR)
    print("cwd:\t"+os.getcwd())
    print("T={}K, nuclear site: {}  =".format(TEMP,specie))
    print("==================================")


    print("1-3/2(<tx^2>+<ty^2>)\t\t={}".format(cq_coef0))
    print("1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)\t={}".format(cq_coef1))
    print()


    cqprime0=cq0*cq_coef0
    cqprime0s.append(cqprime0)
    cqprime1=cq0*cq_coef1
    cqprime1s.append(cqprime1)


    print("Cq0:\t\t{}".format(cq0))
    print("Cq' from coefficient 1-3/2(<>+<>):\t\t{}".format(cqprime0))
    print("Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):\t{}".format(cqprime1))
    nuclear_spin=1
    freq_function=nqr.f1
    print(
    "Computing NQR frequencies for spin:\t{}\nusing function {}\tand simple coefficient".format(nuclear_spin, freq_function)
    )
    print("WARNING:\t eta not adjusted.  Using eta0.")
    fq=freq_function(cqprime0,eta0)
    fq0s.append(fq)
    print("fqs={}".format(freq_function(cqprime0, eta0)))
    print()
    print()

print("##################################"*2)
print("##################################"*2)
print()
print("==================================")
print("          FINAL REPORT T={}K      ".format(TEMP))
print("cwd:\t{}".format(os.getcwd()))
print("==================================")
print("""
target_atom_labels=\t{}\n
av_theta_xs=\t{}\n    
av_theta_ys=\t{}\n  
av_theta_y2s=\t{}\n
av_theta_x2s=\t{}\n 
cq_coef0s=\t{}\n
cq_coef1s=\t{}\n
eta_coefs=\t{}\n
cq0s=\t{}\n
cqprime0s=\t{}\n
cqprime1s=\t{}\n 
eta0s=\t{}\n
etaprimes=\t{}\n
fq0s=\t{}\n 
fqprimes=\t{}\n

    """.format(
    target_atom_labels,
    av_theta_xs,
    av_theta_ys, 
    av_theta_y2s, 
    av_theta_x2s, 
    cq_coef0s, 
    cq_coef1s, 
    eta_coefs, 
    cq0s, 
    cqprime0s, 
    cqprime1s, 
    eta0s, 
    etaprimes, 
    fq0s, 
    fqprimes))





print("cq_coef0s\n---------")
for item in target_atom_labels:
    print(item, cq_coef0s[target_atom_labels.index(item)])
print()


print("cq_coef1s\n---------")
for item in target_atom_labels:
    print(item, cq_coef1s[target_atom_labels.index(item)])
print()


print("cq0s\n---------")
for item in target_atom_labels:
    print(item, cq0s[target_atom_labels.index(item)])
print()


print("cqprime0s\n---------")
for item in target_atom_labels:
    print(item, cqprime0s[target_atom_labels.index(item)])
print()


print("cqprime1s\n---------")
for item in target_atom_labels:
    print(item, cqprime1s[target_atom_labels.index(item)])
print()


print("eta0s\n---------")
for item in target_atom_labels:
    print(item, eta0s[target_atom_labels.index(item)])
print()





endtime=datetime.datetime.now()
runtime=endtime-starttime
runtime_s=runtime.total_seconds()

print("DONE\truntime is {} seconds".format(str(runtime_s)))
print(endtime.ctime())
print("Goodbye.")
print()
# Out:
# Begin on Mon Feb 19 14:25:16 2018
#
# Working dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
#
#
# TEMP:            293
# TARGET_DIR:      /Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# TARGET_SPECIES:  N
#
#
# There are 901 efg files in this directory.
#
# 901 efg files opened without error.
#
# The indices of N atoms are:
# 1 3 4 6 23 25 26 28 37 39 40 42 51 53 54 56
#
# Working on atomic specie:	1
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	1
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 -5.38554329112e-05 	<ty>:	 -0.000608712712609
#  <tx^2>	: 0.0048278311274 	<ty^2>: 0.00377343829864
#
# cq0=	-6.2161
# eta0=	0.52749
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 1  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.9870980958609403
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.9875152321158689
#
# Cq0:		-6.2161
# Cq' from coefficient 1-3/2(<>+<>):		-6.1359004736811915
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-6.1384934343554525
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-1.61831307 -3.79276882 -5.41108189]
#
#
#
# Working on atomic specie:	3
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	3
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 0.0129549392237 	<ty>:	 -0.00500250546187
#  <tx^2>	: 0.0385306699936 	<ty^2>: 0.0240921535901
#
# cq0=	-0.8219
# eta0=	0.52244
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 3  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.9060657646244925
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.9117232085068683
#
# Cq0:		-0.8219
# Cq' from coefficient 1-3/2(<>+<>):		-0.7446954519448704
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-0.749345305071795
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-0.19452935 -0.46125692 -0.65578626]
#
#
#
# Working on atomic specie:	4
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	4
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 0.0166219578871 	<ty>:	 -0.0166653063215
#  <tx^2>	: 0.00324887964095 	<ty^2>: 0.00439949860438
#
# cq0=	-6.0052
# eta0=	0.49195
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 4  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.988527432631997
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.9881028973827027
#
# Cq0:		-6.0052
# Cq' from coefficient 1-3/2(<>+<>):		-5.936304938441669
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-5.933755519362607
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-1.46018261 -3.7221374  -5.18232001]
#
#
#
# Working on atomic specie:	6
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	6
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 0.0191403258131 	<ty>:	 -0.00599394686542
#  <tx^2>	: 0.048776089715 	<ty^2>: 0.0224133655254
#
# cq0=	-0.9285
# eta0=	0.46805
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 6  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.8932158171394281
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.9024701219321487
#
# Cq0:		-0.9285
# Cq' from coefficient 1-3/2(<>+<>):		-0.829350886213959
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-0.8379435082140001
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-0.19408884 -0.52496874 -0.71905759]
#
#
#
# Working on atomic specie:	23
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	23
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 -0.0282687815605 	<ty>:	 0.000130179274136
#  <tx^2>	: 0.0436485625967 	<ty^2>: 0.0111826229611
#
# cq0=	-0.9286
# eta0=	0.46805
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 23  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.9177532216631997
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.9291499839480374
#
# Cq0:		-0.9286
# Cq' from coefficient 1-3/2(<>+<>):		-0.8522256416364472
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-0.8628086750941475
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-0.19944211 -0.53944818 -0.73889028]
#
#
#
# Working on atomic specie:	25
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	25
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 0.00511038442505 	<ty>:	 -0.00677830714018
#  <tx^2>	: 0.00625245679825 	<ty^2>: 0.00370783957117
#
# cq0=	-6.0052
# eta0=	0.49196
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 25  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.9850595554458781
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.9859984428641551
#
# Cq0:		-6.0052
# Cq' from coefficient 1-3/2(<>+<>):		-5.915479642363588
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-5.921117849087825
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-1.45508968 -3.70906489 -5.16415457]
#
#
#
# Working on atomic specie:	26
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	26
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 0.0248692604649 	<ty>:	 -0.00609476878992
#  <tx^2>	: 0.0596521125884 	<ty^2>: 0.0206424840509
#
# cq0=	-0.8217
# eta0=	0.52245
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 26  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.879558105041097
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.8948435403631806
#
# Cq0:		-0.8217
# Cq' from coefficient 1-3/2(<>+<>):		-0.7227328949122694
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-0.7352929371164255
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-0.1887959  -0.44765172 -0.63644762]
#
#
#
# Working on atomic specie:	28
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	28
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 0.00501846913293 	<ty>:	 0.00110473290593
#  <tx^2>	: 0.00185705056975 	<ty^2>: 0.00369656022465
#
# cq0=	-6.2161
# eta0=	0.52749
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 28  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.9916695838084003
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.9909418415974993
#
# Cq0:		-6.2161
# Cq' from coefficient 1-3/2(<>+<>):		-6.1643172999113975
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-6.159793581554215
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-1.62580787 -3.81033404 -5.43614191]
#
#
#
# Working on atomic specie:	37
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	37
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 0.022146037492 	<ty>:	 -0.00190774107955
#  <tx^2>	: 0.0474055993604 	<ty^2>: 0.0221180181006
#
# cq0=	-0.9285
# eta0=	0.46805
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 37  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.8957145738084472
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.904591463114945
#
# Cq0:		-0.9285
# Cq' from coefficient 1-3/2(<>+<>):		-0.8316709817811432
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-0.8399131735022264
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-0.1946318  -0.52643734 -0.72106914]
#
#
#
# Working on atomic specie:	39
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	39
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 0.0233229496263 	<ty>:	 -0.00938984058541
#  <tx^2>	: 0.00383909528317 	<ty^2>: 0.00415735076106
#
# cq0=	-6.0052
# eta0=	0.49195
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 39  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.9880053309336635
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.9878879065969015
#
# Cq0:		-6.0052
# Cq' from coefficient 1-3/2(<>+<>):		-5.933169613322836
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-5.932464456695714
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-1.4594114  -3.72017151 -5.17958291]
#
#
#
# Working on atomic specie:	40
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	40
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 0.00681648584215 	<ty>:	 -0.00892373433077
#  <tx^2>	: 0.0463192167632 	<ty^2>: 0.0260507743353
#
# cq0=	-0.8219
# eta0=	0.52244
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 40  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.8914450133522696
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.8993867971487887
#
# Cq0:		-0.8219
# Cq' from coefficient 1-3/2(<>+<>):		-0.7326786564742304
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-0.7392060085765894
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-0.19139032 -0.45381383 -0.64520415]
#
#
#
# Working on atomic specie:	42
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	42
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 -0.0109678878054 	<ty>:	 -0.0010451331668
#  <tx^2>	: 0.00367883918902 	<ty^2>: 0.00355134275247
#
# cq0=	-6.2161
# eta0=	0.52749
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 42  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.9891547270877635
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.9892051669092518
#
# Cq0:		-6.2161
# Cq' from coefficient 1-3/2(<>+<>):		-6.148684699050247
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-6.1489982380246
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-1.62168485 -3.8006711  -5.42235595]
#
#
#
# Working on atomic specie:	51
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	51
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 -0.01233369719 	<ty>:	 -0.00185895390292
#  <tx^2>	: 0.0418071596862 	<ty^2>: 0.0216932458949
#
# cq0=	-0.9286
# eta0=	0.46805
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 51  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.9047493916282283
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.9118101296407396
#
# Cq0:		-0.9286
# Cq' from coefficient 1-3/2(<>+<>):		-0.8401502850659728
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-0.8467068863843907
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-0.19661617 -0.53180463 -0.7284208 ]
#
#
#
# Working on atomic specie:	53
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	53
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 -0.00173506293501 	<ty>:	 -0.00236299411312
#  <tx^2>	: 0.00531194488377 	<ty^2>: 0.0035159074711
#
# cq0=	-6.0052
# eta0=	0.49196
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 53  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.9867582214677
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.9874209053918545
#
# Cq0:		-6.0052
# Cq' from coefficient 1-3/2(<>+<>):		-5.925680471557833
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-5.929660021059164
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-1.45759888 -3.71546091 -5.17305979]
#
#
#
# Working on atomic specie:	54
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	54
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 8.75812419291e-05 	<ty>:	 -0.0114982775068
#  <tx^2>	: 0.0333119255531 	<ty^2>: 0.01654048067
#
# cq0=	-0.8217
# eta0=	0.52245
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 54  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.9252213906654035
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.931793071699807
#
# Cq0:		-0.8217
# Cq' from coefficient 1-3/2(<>+<>):		-0.7602544167097621
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-0.7656543670157314
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-0.19859746 -0.47089208 -0.66948954]
#
#
#
# Working on atomic specie:	56
# Fetching the angles in file efg.{}.out
# skipped:278
# skipped:400
# skipped:401
# skipped:466
# skipped:499
# skipped:500
# skipped:501
# skipped:601
# skipped:622
# skipped:701
# skipped:801
# skipped:813
# skipped:842
# 900
# Report for atomic specie:	56
# Working Dir:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# <tx>:	 0.0066051901685 	<ty>:	 -0.000921274038724
#  <tx^2>	: 0.00399799061463 	<ty^2>: 0.00355645706155
#
# cq0=	-6.2161
# eta0=	0.52749
# ==================================
# target:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# T=293K, nuclear site: 56  =
# ==================================
# 1-3/2(<tx^2>+<ty^2>)		=0.9886683284857216
# 1-3/2(<tx^2>+<ty^2>-1/2eta0*(<tx^2>-<ty^2>)	=0.9888430068861562
#
# Cq0:		-6.2161
# Cq' from coefficient 1-3/2(<>+<>):		-6.145661196700094
# Cq' from coefficient 1-3/2(<>+<>)+1/2eta(<>-<>)):	-6.146747015105036
# Computing NQR frequencies for spin:	1
# using function <function f1 at 0x10b7dee18>	and simple coefficient
# WARNING:	 eta not adjusted.  Using eta0.
# fqs=[-1.62088741 -3.79880219 -5.4196896 ]
#
#
# ####################################################################
# ####################################################################
#
# ==================================
#           FINAL REPORT T=293K
# cwd:	/Users/altoidnerd/Desktop/nitroamines3/hmx/dt80N6/792928/scfs
# ==================================
#
# target_atom_labels=	[1, 3, 4, 6, 23, 25, 26, 28, 37, 39, 40, 42, 51, 53, 54, 56]
#
# av_theta_xs=	[-5.3855432911185603e-05, 0.012954939223678803, 0.016621957887120724, 0.019140325813115224, -0.028268781560543035, 0.0051103844250525192, 0.024869260464879601, 0.0050184691329330615, 0.022146037492003612, 0.023322949626285883, 0.0068164858421542549, -0.010967887805430256, -0.012333697190031931, -0.0017350629350120846, 8.7581241929113272e-05, 0.0066051901685046681]
#
# av_theta_ys=	[-0.00060871271260947606, -0.0050025054618675043, -0.016665306321520391, -0.0059939468654243433, 0.00013017927413627064, -0.006778307140178446, -0.0060947687899181886, 0.0011047329059261789, -0.0019077410795498315, -0.0093898405854117937, -0.0089237343307717355, -0.0010451331667960784, -0.0018589539029204324, -0.0023629941131186583, -0.011498277506849622, -0.00092127403872356778]
#
# av_theta_y2s=	[0.0037734382986440835, 0.024092153590095512, 0.0043994986043823557, 0.022413365525370838, 0.011182622961125316, 0.0037078395711657034, 0.020642484050857716, 0.0036965602246544415, 0.022118018100602328, 0.0041573507610584721, 0.026050774335299728, 0.0035513427524687573, 0.021693245894943709, 0.003515907471096172, 0.016540480669954349, 0.003556457061554062]
#
# av_theta_x2s=	[0.0048278311273957349, 0.038530669993576155, 0.0032488796409529679, 0.048776089715010434, 0.043648562596741519, 0.0062524567982488724, 0.059652112588410924, 0.001857050569745338, 0.047405599360432871, 0.003839095283165889, 0.04631921676318726, 0.0036788391890221878, 0.04180715968623739, 0.0053119448837705106, 0.033311925553109988, 0.0039979906146315278]
#
# cq_coef0s=	[0.98709809586094033, 0.90606576462449251, 0.98852743263199705, 0.8932158171394281, 0.91775322166319973, 0.98505955544587809, 0.87955810504109699, 0.99166958380840031, 0.89571457380844721, 0.98800533093366349, 0.89144501335226956, 0.98915472708776353, 0.90474939162822832, 0.98675822146769998, 0.92522139066540354, 0.98866832848572161]
#
# cq_coef1s=	[0.98751523211586889, 0.91172320850686828, 0.98810289738270274, 0.90247012193214871, 0.92914998394803738, 0.98599844286415506, 0.89484354036318059, 0.99094184159749932, 0.90459146311494498, 0.98788790659690151, 0.89938679714878866, 0.98920516690925175, 0.9118101296407396, 0.98742090539185445, 0.93179307169980696, 0.98884300688615623]
#
# eta_coefs=	[]
#
# cq0s=	[-6.2161, -0.8219, -6.0052, -0.9285, -0.9286, -6.0052, -0.8217, -6.2161, -0.9285, -6.0052, -0.8219, -6.2161, -0.9286, -6.0052, -0.8217, -6.2161]
#
# cqprime0s=	[-6.1359004736811915, -0.74469545194487041, -5.9363049384416691, -0.82935088621395903, -0.85222564163644721, -5.9154796423635876, -0.72273289491226944, -6.1643172999113975, -0.83167098178114318, -5.9331696133228364, -0.73267865647423036, -6.1486846990502473, -0.84015028506597278, -5.9256804715578326, -0.76025441670976213, -6.145661196700094]
#
# cqprime1s=	[-6.1384934343554525, -0.74934530507179498, -5.9337555193626068, -0.8379435082140001, -0.86280867509414749, -5.9211178490878247, -0.73529293711642552, -6.1597935815542151, -0.83991317350222638, -5.9324644566957137, -0.73920600857658936, -6.1489982380245998, -0.84670688638439073, -5.9296600210591643, -0.76565436701573142, -6.1467470151050358]
#
# eta0s=	[0.52749, 0.52244, 0.49195, 0.46805, 0.46805, 0.49196, 0.52245, 0.52749, 0.46805, 0.49195, 0.52244, 0.52749, 0.46805, 0.49196, 0.52245, 0.52749]
#
# etaprimes=	[]
#
# fq0s=	[array([-1.61831307, -3.79276882, -5.41108189]), array([-0.19452935, -0.46125692, -0.65578626]), array([-1.46018261, -3.7221374 , -5.18232001]), array([-0.19408884, -0.52496874, -0.71905759]), array([-0.19944211, -0.53944818, -0.73889028]), array([-1.45508968, -3.70906489, -5.16415457]), array([-0.1887959 , -0.44765172, -0.63644762]), array([-1.62580787, -3.81033404, -5.43614191]), array([-0.1946318 , -0.52643734, -0.72106914]), array([-1.4594114 , -3.72017151, -5.17958291]), array([-0.19139032, -0.45381383, -0.64520415]), array([-1.62168485, -3.8006711 , -5.42235595]), array([-0.19661617, -0.53180463, -0.7284208 ]), array([-1.45759888, -3.71546091, -5.17305979]), array([-0.19859746, -0.47089208, -0.66948954]), array([-1.62088741, -3.79880219, -5.4196896 ])]
#
# fqprimes=	[]
#
#
#
# cq_coef0s
# ---------
# 1 0.987098095861
# 3 0.906065764624
# 4 0.988527432632
# 6 0.893215817139
# 23 0.917753221663
# 25 0.985059555446
# 26 0.879558105041
# 28 0.991669583808
# 37 0.895714573808
# 39 0.988005330934
# 40 0.891445013352
# 42 0.989154727088
# 51 0.904749391628
# 53 0.986758221468
# 54 0.925221390665
# 56 0.988668328486
#
# cq_coef1s
# ---------
# 1 0.987515232116
# 3 0.911723208507
# 4 0.988102897383
# 6 0.902470121932
# 23 0.929149983948
# 25 0.985998442864
# 26 0.894843540363
# 28 0.990941841597
# 37 0.904591463115
# 39 0.987887906597
# 40 0.899386797149
# 42 0.989205166909
# 51 0.911810129641
# 53 0.987420905392
# 54 0.9317930717
# 56 0.988843006886
#
# cq0s
# ---------
# 1 -6.2161
# 3 -0.8219
# 4 -6.0052
# 6 -0.9285
# 23 -0.9286
# 25 -6.0052
# 26 -0.8217
# 28 -6.2161
# 37 -0.9285
# 39 -6.0052
# 40 -0.8219
# 42 -6.2161
# 51 -0.9286
# 53 -6.0052
# 54 -0.8217
# 56 -6.2161
#
# cqprime0s
# ---------
# 1 -6.13590047368
# 3 -0.744695451945
# 4 -5.93630493844
# 6 -0.829350886214
# 23 -0.852225641636
# 25 -5.91547964236
# 26 -0.722732894912
# 28 -6.16431729991
# 37 -0.831670981781
# 39 -5.93316961332
# 40 -0.732678656474
# 42 -6.14868469905
# 51 -0.840150285066
# 53 -5.92568047156
# 54 -0.76025441671
# 56 -6.1456611967
#
# cqprime1s
# ---------
# 1 -6.13849343436
# 3 -0.749345305072
# 4 -5.93375551936
# 6 -0.837943508214
# 23 -0.862808675094
# 25 -5.92111784909
# 26 -0.735292937116
# 28 -6.15979358155
# 37 -0.839913173502
# 39 -5.9324644567
# 40 -0.739206008577
# 42 -6.14899823802
# 51 -0.846706886384
# 53 -5.92966002106
# 54 -0.765654367016
# 56 -6.14674701511
#
# eta0s
# ---------
# 1 0.52749
# 3 0.52244
# 4 0.49195
# 6 0.46805
# 23 0.46805
# 25 0.49196
# 26 0.52245
# 28 0.52749
# 37 0.46805
# 39 0.49195
# 40 0.52244
# 42 0.52749
# 51 0.46805
# 53 0.49196
# 54 0.52245
# 56 0.52749
#
# DONE	runtime is 1866.798895 seconds
# Mon Feb 19 14:56:23 2018
# Goodbye.
